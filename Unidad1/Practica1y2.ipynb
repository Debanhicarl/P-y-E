# %% [markdown]
# <a href="https://colab.research.google.com/github/Debanhicarl/P-y-E/blob/main/Unidad1/Practica1y2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Sin título.png](data:image/png;base64,...)
# # Probabilidad y estadística
# ## Unidad 1
# ## Práctica 1 y 2: Estadística descriptiva básica e histogramas
# ## Facilitador: Dr. José Gabriel Rodríguez Rivas
# ## Alumna: Ana Debanhi Carmona Loredo

# %%
from statistics import *
# crear lista
g = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100,96]
print(g)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
type(g)
# Out:
# list

# %%
# calcular la media
prom = sum(g) / len(g)
print(prom)
# Out:
# 75.33333333333333

# %%
# función de la librería statistics para calcular la media
prom2 = mean(g)
print(prom2)
# Out:
# 75.33333333333333

# %%
# calcular la mediana con la función med
med = median(g)
print(med)
# Out:
# 76.5

# %%
#calcular la mediana con la función mode
moda = mode(g)
print(moda)
# Out:
# 70

# %%
# se utiliza la función multimode en caso de que haya más de una moda
moda2 = multimode(g)
print(moda2)
# Out:
# [70, 100]

# %%
# tiempos de 10 alumnos que correrán 10 metros
tiempos = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
# determinar el tiempo promedio
print("El tiempo promedio de los corredores es:", mean(tiempos))
# Out:
# El tiempo promedio de los corredores es: 17.322

# %%
# sacar la mediana
print("La media de los tiempos de los corredores es:", median(tiempos))
# Out:
# La media de los tiempos de los corredores es: 17.2

# %%
# determinar la moda
print("La moda de los tiempos de los corredores es:", mode(tiempos))
# Out:
# La moda de los tiempos de los corredores es: 15.1

# %%
# determinar las multiples modas
print("Las modas de los tiempos son:", multimode(tiempos))
# Out:
# Las modas de los tiempos son: [15.1, 17.2]

# %%
# Librería para generar numeros aleatorios
import random

# %%
# generar los numeros aleatorios con el ciclo for
fabrica1 = []
for i in range (100):
  num_aleatorio1 = round( random.uniform(50, 100),2)
  fabrica1.append(num_aleatorio1)
print(fabrica1)
# Out:
# [77.17, 81.56, 65.75, 91.46, 71.11, 99.14, 73.03, 64.34, 54.73, 71.33, 77.27, 50.55, 76.92, 71.59, 68.71, 58.93, 86.42, 57.59, 53.68, 81.95, 76.49, 68.53, 73.84, 84.95, 91.36, 62.64, 62.16, 67.13, 91.96, 56.16, 51.95, 75.38, 53.99, 89.62, 59.01, 99.84, 50.41, 80.87, 61.87, 81.76, 62.22, 69.61, 78.55, 55.63, 54.73, 60.52, 75.37, 50.36, 78.6, 74.14, 77.13, 60.05, 75.57, 84.37, 69.67, 53.36, 81.67, 71.56, 58.83, 87.31, 98.33, 54.16, 58.48, 83.47, 58.54, 61.38, 54.14, 86.81, 83.84, 77.67, 58.1, 54.47, 92.36, 64.73, 87.57, 62.2, 77.52, 61.39, 51.52, 79.12, 88.05, 90.58, 53.39, 88.34, 66.56, 62.23, 85.6, 57.44, 70.39, 68.93, 61.51, 60.4, 96.03, 52.55, 95.96, 68.52, 66.49, 93.51, 64.49, 82.81]

# %%
fabrica2 = []
for i in range (100):
  num_aleatorio2 = round( random.uniform(50, 100),2)
  fabrica2.append(num_aleatorio2)
print(fabrica2)
# Out:
# [82.46, 61.41, 92.0, 54.8, 52.14, 58.8, 95.93, 78.91, 86.66, 88.03, 82.37, 79.91, 66.33, 50.47, 94.19, 64.61, 91.89, 65.3, 68.31, 99.19, 91.35, 90.9, 82.69, 90.5, 62.83, 95.27, 69.04, 91.55, 57.35, 59.54, 66.96, 97.54, 66.76, 79.54, 76.1, 52.68, 71.7, 56.88, 69.79, 54.89, 84.91, 91.15, 69.08, 60.52, 56.69, 88.15, 87.15, 81.21, 82.47, 70.0, 81.3, 88.17, 92.87, 53.51, 64.1, 84.25, 59.42, 77.55, 90.36, 95.7, 60.89, 90.24, 72.98, 98.5, 80.53, 76.71, 68.58, 89.77, 91.88, 89.07, 59.8, 94.76, 58.08, 71.49, 66.99, 60.25, 78.64, 65.0, 74.32, 55.77, 66.09, 50.17, 50.27, 71.15, 57.31, 72.81, 50.46, 72.76, 96.75, 80.09, 53.92, 81.96, 90.43, 66.05, 99.69, 69.28, 95.4, 85.72, 57.61, 63.17]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Producción diaria de fábrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de fábrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de fábrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de fábrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
print("Valores de la fabrica 1")
print("La media es :", media1)
print("La mediana es : ", mediana1)
print("La moda es :", moda1)
# Out:
# Valores de la fabrica 1
# La media es : 71.3198
# La mediana es :  70.03
# La moda es : 54.73

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print("Valores de la fabrica 2")
print("La media es :", media2)
print("La mediana es : ", mediana2)
print("La moda es :", moda2)
# Out:
# Valores de la fabrica 2
# La media es : 74.9147
# La mediana es :  73.65
# La moda es : 82.46

# %%
fig, (ax1, ax2)=plt.subplots(nrows =1, ncols=2, figsize= (10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle= 'dashed', linewidth=2, label = 'Media')
plt.axvline(mediana1, color='r', linestyle= 'dashed', linewidth=2, label = 'Mediana')
plt.axvline(moda1, color='y', linestyle= 'dashed', linewidth=2, label = 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle= 'dashed', linewidth=2, label = 'Media')
plt.axvline(mediana2, color='r', linestyle= 'dashed', linewidth=2, label = 'Mediana')
plt.axvline(moda2, color='y', linestyle= 'dashed', linewidth=2, label = 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()
